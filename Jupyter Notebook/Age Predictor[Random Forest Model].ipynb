# %% [markdown]
# # Age Predictor[WHO DataSet]

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## Preparing The Data

# %%
df=pd.read_csv('who.csv') 
df.dropna(inplace= True)

# %%
df['Developed Country']=df['Status']=='Developed'

# %%
df2=df.drop(['Status','Country'],axis=1).copy()

# %%
c_m=df2.corr() 
c_m['Life expectancy '].sort_values(ascending=False)
# Out:
# Life expectancy                    1.000000
# Schooling                          0.727630
# Income composition of resources    0.721083
#  BMI                               0.542042
# Developed Country                  0.442798
# GDP                                0.441322
# percentage expenditure             0.409631
# Alcohol                            0.402718
# Diphtheria                         0.341331
# Polio                              0.327294
# Hepatitis B                        0.199935
# Total expenditure                  0.174718
# Year                               0.050771
# Population                        -0.022305
# Measles                           -0.068881
# infant deaths                     -0.169074
# under-five deaths                 -0.192265
#  thinness 5-9 years               -0.457508
#  thinness  1-19 years             -0.457838
#  HIV/AIDS                         -0.592236
# Adult Mortality                   -0.702523
# Name: Life expectancy , dtype: float64

# %%
df2.T
# Out:
#                                        0           1           2     \
# Year                                   2015        2014        2013
# Life expectancy                        65.0        59.9        59.9
# Adult Mortality                       263.0       271.0       268.0
# infant deaths                            62          64          66
# Alcohol                                0.01        0.01        0.01
# percentage expenditure            71.279624   73.523582   73.219243
# Hepatitis B                            65.0        62.0        64.0
# Measles                                1154         492         430
#  BMI                                   19.1        18.6        18.1
# under-five deaths                        83          86          89
# Polio                                   6.0        58.0        62.0
# Total expenditure                      8.16        8.18        8.13
# Diphtheria                             65.0        62.0        64.0
#  HIV/AIDS                               0.1         0.1         0.1
# GDP                               584.25921  612.696514  631.744976
# Population                       33736494.0    327582.0  31731688.0
#  thinness  1-19 years                  17.2        17.5        17.7
#  thinness 5-9 years                    17.3        17.5        17.7
# Income composition of resources       0.479       0.476        0.47
# Schooling                              10.1        10.0         9.9
# Developed Country                     False       False       False
#
#                                       3          4          5           6     \
# Year                                  2012       2011       2010        2009
# Life expectancy                       59.5       59.2       58.8        58.6
# Adult Mortality                      272.0      275.0      279.0       281.0
# infant deaths                           69         71         74          77
# Alcohol                               0.01       0.01       0.01        0.01
# percentage expenditure           78.184215   7.097109  79.679367   56.762217
# Hepatitis B                           67.0       68.0       66.0        63.0
# Measles                               2787       3013       1989        2861
#  BMI                                  17.6       17.2       16.7        16.2
# under-five deaths                       93         97        102         106
# Polio                                 67.0       68.0       66.0        63.0
# Total expenditure                     8.52       7.87        9.2        9.42
# Diphtheria                            67.0       68.0       66.0        63.0
#  HIV/AIDS                              0.1        0.1        0.1         0.1
# GDP                                669.959  63.537231  553.32894  445.893298
# Population                       3696958.0  2978599.0  2883167.0    284331.0
#  thinness  1-19 years                 17.9       18.2       18.4        18.6
#  thinness 5-9 years                   18.0       18.2       18.4        18.7
# Income composition of resources      0.463      0.454      0.448       0.434
# Schooling                              9.8        9.5        9.2         8.9
# Developed Country                    False      False      False       False
#
#                                        7           8          9     ...  \
# Year                                   2008        2007       2006  ...
# Life expectancy                        58.1        57.5       57.3  ...
# Adult Mortality                       287.0       295.0      295.0  ...
# infant deaths                            80          82         84  ...
# Alcohol                                0.03        0.02       0.03  ...
# percentage expenditure            25.873925   10.910156  17.171518  ...
# Hepatitis B                            64.0        63.0       64.0  ...
# Measles                                1599        1141       1990  ...
#  BMI                                   15.7        15.2       14.7  ...
# under-five deaths                       110         113        116  ...
# Polio                                  64.0        63.0       58.0  ...
# Total expenditure                      8.33        6.73       7.43  ...
# Diphtheria                             64.0        63.0       58.0  ...
#  HIV/AIDS                               0.1         0.1        0.1  ...
# GDP                              373.361116  369.835796  272.56377  ...
# Population                        2729431.0  26616792.0  2589345.0  ...
#  thinness  1-19 years                  18.8        19.0       19.2  ...
#  thinness 5-9 years                    18.9        19.1       19.3  ...
# Income composition of resources       0.433       0.415      0.405  ...
# Schooling                               8.7         8.4        8.1  ...
# Developed Country                     False       False      False  ...
#
#                                       2928        2929        2930  \
# Year                                  2009        2008        2007
# Life expectancy                       50.0        48.2        46.6
# Adult Mortality                      587.0       632.0        67.0
# infant deaths                           30          30          29
# Alcohol                               4.64        3.56        3.88
# percentage expenditure            1.040021   20.843429   29.814566
# Hepatitis B                           73.0        75.0        72.0
# Measles                                853           0         242
#  BMI                                  29.0        28.6        28.2
# under-five deaths                       45          46          46
# Polio                                 69.0        75.0        73.0
# Total expenditure                     6.26        4.96        4.47
# Diphtheria                            73.0        75.0        73.0
#  HIV/AIDS                             18.1        20.5        23.7
# GDP                              65.824121  325.678573  396.998217
# Population                       1381599.0  13558469.0   1332999.0
#  thinness  1-19 years                  7.5         7.8         8.2
#  thinness 5-9 years                    7.4         7.8         8.2
# Income composition of resources      0.419       0.421       0.414
# Schooling                              9.9         9.7         9.6
# Developed Country                    False       False       False
#
#                                        2931       2932        2933  \
# Year                                   2006       2005        2004
# Life expectancy                        45.4       44.6        44.3
# Adult Mortality                         7.0      717.0       723.0
# infant deaths                            28         28          27
# Alcohol                                4.57       4.14        4.36
# percentage expenditure            34.262169   8.717409         0.0
# Hepatitis B                            68.0       65.0        68.0
# Measles                                 212        420          31
#  BMI                                   27.9       27.5        27.1
# under-five deaths                        45         43          42
# Polio                                  71.0       69.0        67.0
# Total expenditure                      5.12       6.44        7.13
# Diphtheria                              7.0       68.0        65.0
#  HIV/AIDS                              26.8       30.3        33.6
# GDP                              414.796232  444.76575  454.366654
# Population                       13124267.0   129432.0  12777511.0
#  thinness  1-19 years                   8.6        9.0         9.4
#  thinness 5-9 years                     8.6        9.0         9.4
# Income composition of resources       0.408      0.406       0.407
# Schooling                               9.5        9.3         9.2
# Developed Country                     False      False       False
#
#                                        2934      2935        2936        2937
# Year                                   2003      2002        2001        2000
# Life expectancy                        44.5      44.8        45.3        46.0
# Adult Mortality                       715.0      73.0       686.0       665.0
# infant deaths                            26        25          25          24
# Alcohol                                4.06      4.43        1.72        1.68
# percentage expenditure                  0.0       0.0         0.0         0.0
# Hepatitis B                             7.0      73.0        76.0        79.0
# Measles                                 998       304         529        1483
#  BMI                                   26.7      26.3        25.9        25.5
# under-five deaths                        41        40          39          39
# Polio                                   7.0      73.0        76.0        78.0
# Total expenditure                      6.52      6.53        6.16         7.1
# Diphtheria                             68.0      71.0        75.0        78.0
#  HIV/AIDS                              36.7      39.8        42.1        43.5
# GDP                              453.351155  57.34834  548.587312  547.358878
# Population                       12633897.0  125525.0  12366165.0  12222251.0
#  thinness  1-19 years                   9.8       1.2         1.6        11.0
#  thinness 5-9 years                     9.9       1.3         1.7        11.2
# Income composition of resources       0.418     0.427       0.427       0.434
# Schooling                               9.5      10.0         9.8         9.8
# Developed Country                     False     False       False       False
#
# [21 rows x 1649 columns]

# %%
X=df2.drop('Life expectancy ',axis=1).copy().values

# %%
X
# Out:
# array([[2015, 263.0, 62, ..., 0.479, 10.1, False],
#        [2014, 271.0, 64, ..., 0.476, 10.0, False],
#        [2013, 268.0, 66, ..., 0.47, 9.9, False],
#        ...,
#        [2002, 73.0, 25, ..., 0.427, 10.0, False],
#        [2001, 686.0, 25, ..., 0.427, 9.8, False],
#        [2000, 665.0, 24, ..., 0.434, 9.8, False]], dtype=object)

# %%
y=df2['Life expectancy '].copy().values

# %%
y
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=209)

# %% [markdown]
# ## Training The Model

# %%
model=RandomForestRegressor() 
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Testing The Model

# %%
model.predict(X_test[:10])
# Out:
# array([58.268, 79.331, 53.191, 67.461, 45.013, 80.116, 69.51 , 64.445,
#        49.635, 81.291])

# %%
y_test[:10]
# Out:
# array([58.1, 79.1, 51.1, 68.7, 44.3, 78.8, 75. , 65. , 46.2, 80. ])
